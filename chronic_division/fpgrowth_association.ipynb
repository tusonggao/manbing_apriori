# %%
import time
import pandas as pd
import numpy as np
import json
from pyspark.mllib.fpm import FPGrowth as FPGrowth_MLlib
from pyspark.ml.fpm import FPGrowth
from pyspark import SparkConf, SparkContext
from pyspark.sql.session import SparkSession

print('load library successfully')
# Out:
# load library successfully

# %%
conf = (SparkConf()
         .setMaster("local")
         .setAppName("My app")
         .set("spark.executor.memory", "1g"))
sc = SparkContext(conf = conf)
spark = SparkSession(sc)
# sc = SparkContext(appName="FPGrowth")
print('spark version is ', sc.version)

# %%
# data = sc.textFile("./data/sample_fpgrowth.txt")
# transactions = data.map(lambda line: line.strip().split(' '))
# model = FPGrowth.train(transactions, minSupport=0.2, numPartitions=10)

# data = sc.textFile("./data/samples_ttt.txt")
data = sc.textFile("./data/samples_full.txt")
transactions = data.map(lambda line: line.strip().split('###'))

print('start fp growth...')
start_t = time.time()
model = FPGrowth_MLlib.train(transactions, minSupport=0.001, numPartitions=10)
result = model.freqItemsets().collect()
for fi in result:
    print(fi)
print('cost time: ', time.time()-start_t)
# Out:
# start fp growth...
# FreqItemset(items=['甲巯咪唑片'], freq=1340)
# FreqItemset(items=['丙酸氟替卡松鼻喷雾剂'], freq=1866)
# FreqItemset(items=['五子衍宗丸'], freq=3172)
# FreqItemset(items=['氨甲环酸片'], freq=1699)
# FreqItemset(items=['雌二醇片/雌二醇地屈孕酮片复合包装'], freq=2290)
# FreqItemset(items=['沙美特罗替卡松粉吸入剂'], freq=5071)
# FreqItemset(items=['磷酸奥司他韦颗粒'], freq=1065)
# FreqItemset(items=['维生素D滴剂'], freq=1254)
# FreqItemset(items=['足光散'], freq=992)
# FreqItemset(items=['红核妇结洗液'], freq=1162)
# FreqItemset(items=['丹参酮胶囊'], freq=1544)
# FreqItemset(items=['维生素C加天然维生素E咀嚼片'], freq=2007)
# FreqItemset(items=['人初抑菌喷雾剂'], freq=1373)
# FreqItemset(items=['人初抑菌喷雾剂', '名流水晶狼牙套'], freq=1253)
# FreqItemset(items=['人初抑菌喷雾剂', '名流水晶狼牙套', '天然胶乳橡胶避孕套'], freq=1252)
# FreqItemset(items=['人初抑菌喷雾剂', '名流水晶狼牙套', '杜蕾斯人体润滑液 爽滑快感装'], freq=1252)
# FreqItemset(items=['人初抑菌喷雾剂', '名流水晶狼牙套', '杜蕾斯人体润滑液 爽滑快感装', '天然胶乳橡胶避孕套'], freq=1252)
# FreqItemset(items=['人初抑菌喷雾剂', '天然胶乳橡胶避孕套'], freq=1256)
# FreqItemset(items=['人初抑菌喷雾剂', '杜蕾斯人体润滑液 爽滑快感装'], freq=1254)
# FreqItemset(items=['人初抑菌喷雾剂', '杜蕾斯人体润滑液 爽滑快感装', '天然胶乳橡胶避孕套'], freq=1252)
# FreqItemset(items=['人初抑菌喷雾剂', '男用湿巾'], freq=1248)
# FreqItemset(items=['人初抑菌喷雾剂', '男用湿巾', '名流水晶狼牙套'], freq=1245)
# FreqItemset(items=['人初抑菌喷雾剂', '男用湿巾', '名流水晶狼牙套', '天然胶乳橡胶避孕套'], freq=1245)
# FreqItemset(items=['人初抑菌喷雾剂', '男用湿巾', '名流水晶狼牙套', '杜蕾斯人体润滑液 爽滑快感装'], freq=1245)
# FreqItemset(items=['人初抑菌喷雾剂', '男用湿巾', '名流水晶狼牙套', '杜蕾斯人体润滑液 爽滑快感装', '天然胶乳橡胶避孕套'], freq=1245)
# FreqItemset(items=['人初抑菌喷雾剂', '男用湿巾', '天然胶乳橡胶避孕套'], freq=1245)
# FreqItemset(items=['人初抑菌喷雾剂', '男用湿巾', '杜蕾斯人体润滑液 爽滑快感装'], freq=1245)
# FreqItemset(items=['人初抑菌喷雾剂', '男用湿巾', '杜蕾斯人体润滑液 爽滑快感装', '天然胶乳橡胶避孕套'], freq=1245)
# FreqItemset(items=['麝香痔疮栓'], freq=1025)
# FreqItemset(items=['酿粉刺平精华水'], freq=3431)
# FreqItemset(items=['避孕套'], freq=1752)
# FreqItemset(items=['阿德福韦酯片'], freq=2578)
# FreqItemset(items=['抗病毒口服液'], freq=945)
# FreqItemset(items=['布洛芬缓释胶囊'], freq=1178)
# FreqItemset(items=['感冒灵颗粒'], freq=7237)
# FreqItemset(items=['草木犀流浸液片'], freq=1432)
# FreqItemset(items=['盐酸特比萘芬片'], freq=1105)
# FreqItemset(items=['天然维生素E软胶囊'], freq=1301)
# FreqItemset(items=['维生素B族片'], freq=1830)
# FreqItemset(items=['硫酸氢氯吡格雷片'], freq=2821)
# FreqItemset(items=['采血针'], freq=1587)
# FreqItemset(items=['美沙拉秦肠溶片'], freq=2101)
# FreqItemset(items=['烟酰胺片(力生)'], freq=1044)
# FreqItemset(items=['奥利司他胶囊'], freq=4039)
# FreqItemset(items=['盐酸多奈哌齐片'], freq=1226)
# FreqItemset(items=['糠酸莫米松乳膏'], freq=972)
# FreqItemset(items=['拉米夫定片'], freq=1129)
# FreqItemset(items=['维生素E软胶囊'], freq=1497)
# FreqItemset(items=['枸橼酸西地那非片'], freq=61089)
# FreqItemset(items=['nan'], freq=1983)
# FreqItemset(items=['丙戊酸镁缓释片'], freq=1371)
# FreqItemset(items=['屈螺酮炔雌醇片(优思明)'], freq=1750)
# FreqItemset(items=['板蓝根颗粒'], freq=3393)
# FreqItemset(items=['伊曲康唑胶囊'], freq=942)
# FreqItemset(items=['玻璃体温计'], freq=2574)
# FreqItemset(items=['玻璃体温计', '儿童退热贴'], freq=2486)
# FreqItemset(items=['创口贴'], freq=6786)
# FreqItemset(items=['创口贴', '一次性使用口罩'], freq=5475)
# FreqItemset(items=['创口贴', '一次性使用口罩', '医用棉签'], freq=5452)
# FreqItemset(items=['创口贴', '医用棉签'], freq=5489)
# FreqItemset(items=['氨酚羟考酮片'], freq=1093)
# FreqItemset(items=['氟比洛芬凝胶贴膏'], freq=1024)
# FreqItemset(items=['苯溴马隆片'], freq=1300)
# FreqItemset(items=['百乐眠胶囊'], freq=1587)
# FreqItemset(items=['硫酸氨基葡萄糖胶囊'], freq=1177)
# FreqItemset(items=['复方醋酸地塞米松乳膏'], freq=1426)
# FreqItemset(items=['米诺地尔酊'], freq=2085)
# FreqItemset(items=['葡萄糖酸钙锌口服溶液'], freq=1826)
# FreqItemset(items=['卡泊三醇软膏'], freq=4027)
# FreqItemset(items=['马来酸氟伏沙明片'], freq=971)
# FreqItemset(items=['复方利多卡因乳膏'], freq=2799)
# FreqItemset(items=['进口诺丝避孕套 10只 惊喜装天然胶乳橡胶避孕套'], freq=22513)
# FreqItemset(items=['进口诺丝避孕套 10只 惊喜装天然胶乳橡胶避孕套', '枸橼酸西地那非片'], freq=16841)
# FreqItemset(items=['二硫化硒洗剂'], freq=1127)
# FreqItemset(items=['莫匹罗星软膏'], freq=1044)
# FreqItemset(items=['盐酸二甲双胍缓释片'], freq=1336)
# FreqItemset(items=['京都念慈菴蜜炼川贝枇杷膏'], freq=1676)
# FreqItemset(items=['硒酵母片'], freq=1215)
# FreqItemset(items=['迈之灵片'], freq=1490)
# FreqItemset(items=['氢醌乳膏'], freq=2261)
# FreqItemset(items=['盐酸舍曲林片'], freq=4731)
# FreqItemset(items=['地奈德乳膏'], freq=1064)
# FreqItemset(items=['酒精消毒片'], freq=1866)
# FreqItemset(items=['瑞舒伐他汀钙片'], freq=3138)
# FreqItemset(items=['鼻渊通窍颗粒'], freq=1252)
# FreqItemset(items=['补中益气丸'], freq=990)
# FreqItemset(items=['男用湿巾'], freq=1540)
# FreqItemset(items=['男用湿巾', '名流水晶狼牙套'], freq=1254)
# FreqItemset(items=['男用湿巾', '名流水晶狼牙套', '天然胶乳橡胶避孕套'], freq=1248)
# FreqItemset(items=['男用湿巾', '名流水晶狼牙套', '杜蕾斯人体润滑液 爽滑快感装'], freq=1246)
# FreqItemset(items=['男用湿巾', '名流水晶狼牙套', '杜蕾斯人体润滑液 爽滑快感装', '天然胶乳橡胶避孕套'], freq=1246)
# FreqItemset(items=['男用湿巾', '天然胶乳橡胶避孕套'], freq=1258)
# FreqItemset(items=['男用湿巾', '杜蕾斯人体润滑液 爽滑快感装'], freq=1248)
# FreqItemset(items=['男用湿巾', '杜蕾斯人体润滑液 爽滑快感装', '天然胶乳橡胶避孕套'], freq=1246)
# FreqItemset(items=['男用湿巾', '枸橼酸西地那非片'], freq=957)
# FreqItemset(items=['托吡酯片'], freq=1162)
# FreqItemset(items=['盐酸二甲双胍片'], freq=2081)
# FreqItemset(items=['卡泊三醇倍他米松软膏'], freq=1408)
# FreqItemset(items=['复方氨酚烷胺片'], freq=1822)
# FreqItemset(items=['引阳索胶囊'], freq=3961)
# FreqItemset(items=['孟鲁司特钠片'], freq=2794)
# FreqItemset(items=['阿维A胶囊'], freq=961)
# FreqItemset(items=['阿立哌唑片'], freq=1126)
# FreqItemset(items=['约斯夫特大片创可贴(6贴装)'], freq=11762)
# FreqItemset(items=['维D钙咀嚼片'], freq=1044)
# FreqItemset(items=['埃索美拉唑镁肠溶片'], freq=1335)
# FreqItemset(items=['积雪苷霜软膏'], freq=1674)
# FreqItemset(items=['多磺酸粘多糖乳膏'], freq=1214)
# FreqItemset(items=['康妇消炎栓'], freq=1466)
# FreqItemset(items=['4维空间迷你G点震动棒'], freq=2256)
# FreqItemset(items=['阿莫西林胶囊'], freq=4578)
# FreqItemset(items=['生精片'], freq=1863)
# FreqItemset(items=['人初油喷雾剂(人初油)'], freq=983)
# FreqItemset(items=['玻尿酸补水保湿面膜'], freq=3114)
# FreqItemset(items=['地屈孕酮片'], freq=1160)
# FreqItemset(items=['普瑞巴林胶囊'], freq=1063)
# FreqItemset(items=['乳果糖口服溶液'], freq=1366)
# FreqItemset(items=['复方α-酮酸片'], freq=1247)
# FreqItemset(items=['叶酸片'], freq=1747)
# FreqItemset(items=['赖斯康维生素C咀嚼片'], freq=931)
# FreqItemset(items=['左乙拉西坦片'], freq=2511)
# FreqItemset(items=['葛洪养生论光碟'], freq=1535)
# FreqItemset(items=['葛洪养生论光碟', '足浴方剂'], freq=1458)
# FreqItemset(items=['葛洪养生论光碟', '足浴方剂', '桂龙药膏'], freq=1273)
# FreqItemset(items=['葛洪养生论光碟', '桂龙药膏'], freq=1348)
# FreqItemset(items=['葛洪养生论光碟', '葛洪养生论书'], freq=1529)
# FreqItemset(items=['葛洪养生论光碟', '葛洪养生论书', '足浴方剂'], freq=1453)
# FreqItemset(items=['葛洪养生论光碟', '葛洪养生论书', '足浴方剂', '桂龙药膏'], freq=1268)
# FreqItemset(items=['葛洪养生论光碟', '葛洪养生论书', '桂龙药膏'], freq=1342)
# FreqItemset(items=['猴头菌提取物颗粒'], freq=1092)
# FreqItemset(items=['非那雄胺片'], freq=6568)
# FreqItemset(items=['乳酸菌素片'], freq=1977)
# FreqItemset(items=['伤湿止痛膏'], freq=3363)
# FreqItemset(items=['辛伐他汀片'], freq=1019)
# FreqItemset(items=['蒲地蓝消炎片'], freq=1286)
# FreqItemset(items=['七叶洋地黄双苷滴眼液'], freq=1582)
# FreqItemset(items=['苦参凝胶'], freq=1177)
# FreqItemset(items=['来氟米特片'], freq=1465)
# FreqItemset(items=['盐酸普拉克索片'], freq=2252)
# FreqItemset(items=['异维A酸软胶囊'], freq=4508)
# FreqItemset(items=['缬沙坦氨氯地平片(Ⅰ)'], freq=1853)
# FreqItemset(items=['他克莫司软膏'], freq=3037)
# FreqItemset(items=['珊瑚癣净'], freq=982)
# FreqItemset(items=['磷酸西格列汀片'], freq=1160)
# FreqItemset(items=['盐酸苯海索片'], freq=1357)
# FreqItemset(items=['复方谷氨酰胺肠溶胶囊'], freq=1062)
# FreqItemset(items=['转移因子胶囊'], freq=1247)
# FreqItemset(items=['金锁固精丸'], freq=1743)
# FreqItemset(items=['塞来昔布胶囊'], freq=1532)
# FreqItemset(items=['拉莫三嗪片'], freq=2503)
# FreqItemset(items=['阿达帕林凝胶'], freq=6344)
# FreqItemset(items=['甲氨蝶呤片'], freq=1968)
# FreqItemset(items=['七鞭回春乐胶囊'], freq=1018)
# FreqItemset(items=['奥美拉唑肠溶胶囊'], freq=3341)
# FreqItemset(items=['人初油抑菌喷雾剂(升级版)'], freq=929)
# FreqItemset(items=['盐酸左氧氟沙星胶囊'], freq=1177)
# FreqItemset(items=['美沙拉秦缓释颗粒'], freq=1399)
# FreqItemset(items=['维生素AD滴剂'], freq=1087)
# FreqItemset(items=['硝呋太尔制霉素阴道软胶囊'], freq=1281)
# FreqItemset(items=['恩替卡韦胶囊'], freq=1803)
# FreqItemset(items=['肾宝片'], freq=2771)
# FreqItemset(items=['依托考昔片'], freq=1581)
# FreqItemset(items=['加味逍遥丸'], freq=960)
# FreqItemset(items=['胸腺肽肠溶片'], freq=1121)
# FreqItemset(items=['医用棉签'], freq=11293)
# FreqItemset(items=['左甲状腺素钠片'], freq=2063)
# FreqItemset(items=['咽炎片(999)'], freq=3829)
# FreqItemset(items=['咽炎片(999)', '健胃消食片'], freq=3699)
# FreqItemset(items=['咪喹莫特乳膏'], freq=1335)
# FreqItemset(items=['男宝胶囊'], freq=1043)
# FreqItemset(items=['维生素B6片'], freq=1672)
# FreqItemset(items=['卡马西平片'], freq=1212)
# FreqItemset(items=['诺氟沙星胶囊'], freq=1158)
# FreqItemset(items=['复方氨酚烷胺胶囊'], freq=1528)
# FreqItemset(items=['马应龙麝香痔疮膏'], freq=1968)
# FreqItemset(items=['双飞人'], freq=1354)
# FreqItemset(items=['双飞人', '电子体温计'], freq=1017)
# FreqItemset(items=['双飞人', '电子体温计', '感冒灵颗粒'], freq=1009)
# FreqItemset(items=['双飞人', '感冒灵颗粒'], freq=1033)
# FreqItemset(items=['名流水晶狼牙套'], freq=1738)
# FreqItemset(items=['名流水晶狼牙套', '天然胶乳橡胶避孕套'], freq=1295)
# FreqItemset(items=['名流水晶狼牙套', '杜蕾斯人体润滑液 爽滑快感装'], freq=1270)
# FreqItemset(items=['名流水晶狼牙套', '杜蕾斯人体润滑液 爽滑快感装', '天然胶乳橡胶避孕套'], freq=1254)
# FreqItemset(items=['名流水晶狼牙套', '枸橼酸西地那非片'], freq=947)
# FreqItemset(items=['玻璃酸钠滴眼液'], freq=3340)
# FreqItemset(items=['养血生发胶囊'], freq=1018)
# FreqItemset(items=['孟鲁司特钠咀嚼片'], freq=2492)
# FreqItemset(items=['奥拉西坦胶囊'], freq=1173)
# FreqItemset(items=['归脾丸'], freq=925)
# FreqItemset(items=['复方酮康唑发用洗剂'], freq=1397)
# FreqItemset(items=['达格列净片'], freq=1086)
# FreqItemset(items=['健胃消食片'], freq=6283)
# FreqItemset(items=['克霉唑阴道片'], freq=1792)
# FreqItemset(items=['盐酸度洛西汀肠溶胶囊'], freq=1281)
# FreqItemset(items=['拔罐器'], freq=2726)
# FreqItemset(items=['拔罐器', '伤湿止痛膏'], freq=2616)
# FreqItemset(items=['依巴斯汀片'], freq=1580)
# FreqItemset(items=['杜蕾斯人体润滑液 爽滑快感装'], freq=2062)
# FreqItemset(items=['杜蕾斯人体润滑液 爽滑快感装', '天然胶乳橡胶避孕套'], freq=1330)
# FreqItemset(items=['杜蕾斯人体润滑液 爽滑快感装', '枸橼酸西地那非片'], freq=961)
# FreqItemset(items=['一次性使用口罩'], freq=11254)
# FreqItemset(items=['一次性使用口罩', '医用棉签'], freq=5880)
# FreqItemset(items=['硝苯地平控释片'], freq=1040)
# FreqItemset(items=['阿司匹林肠溶片'], freq=3827)
# FreqItemset(items=['洁尔阴洗液'], freq=959)
# FreqItemset(items=['头孢拉定胶囊'], freq=1207)
# FreqItemset(items=['布地奈德鼻喷雾剂'], freq=1457)
# FreqItemset(items=['白芍总苷胶囊'], freq=1119)
# FreqItemset(items=['复方肝素钠尿囊素凝胶'], freq=1849)
# FreqItemset(items=['头孢克肟分散片'], freq=1331)
# FreqItemset(items=['创可贴'], freq=2985)
# FreqItemset(items=['富马酸比索洛尔片'], freq=1647)
# FreqItemset(items=['碳酸钙D3片'], freq=2221)
# FreqItemset(items=['VD钙片(中老年型)'], freq=4451)
# FreqItemset(items=['复方甘草酸苷胶囊'], freq=1060)
# FreqItemset(items=['肾石通颗粒'], freq=982)
# FreqItemset(items=['阿奇霉素片'], freq=1244)
# FreqItemset(items=['盐酸坦索罗辛缓释胶囊'], freq=1575)
# FreqItemset(items=['维生素B2片'], freq=1171)
# FreqItemset(items=['左氧氟沙星片'], freq=2059)
# FreqItemset(items=['风油精'], freq=1397)
# FreqItemset(items=['非布司他片'], freq=3823)
# FreqItemset(items=['蒲地蓝消炎口服液'], freq=1790)
# FreqItemset(items=['痘印修护精华液'], freq=1036)
# FreqItemset(items=['米诺地尔搽剂'], freq=959)
# FreqItemset(items=['复方酮康唑软膏'], freq=1203)
# FreqItemset(items=['恩替卡韦片'], freq=2722)
# FreqItemset(items=['天然胶乳橡胶避孕套'], freq=11017)
# FreqItemset(items=['天然胶乳橡胶避孕套', '枸橼酸西地那非片'], freq=4815)
# FreqItemset(items=['康复新液'], freq=1113)
# FreqItemset(items=['左氧氟沙星滴眼液'], freq=1455)
# FreqItemset(items=['复方氨肽素片'], freq=1329)
# FreqItemset(items=['复方甲氧那明胶囊'], freq=1841)
# FreqItemset(items=['丙戊酸钠缓释片'], freq=2918)
# FreqItemset(items=['复合维生素B片'], freq=1635)
# FreqItemset(items=['糠酸莫米松鼻喷雾剂'], freq=2214)
# FreqItemset(items=['左卡尼汀口服溶液'], freq=1057)
# FreqItemset(items=['电子体温计'], freq=4345)
# FreqItemset(items=['电子体温计', '感冒灵颗粒'], freq=1125)
# FreqItemset(items=['氯氮平片'], freq=1244)
# FreqItemset(items=['复方鳖甲软肝片'], freq=981)
# FreqItemset(items=['铁盒'], freq=1150)
# FreqItemset(items=['铁盒', '枸橼酸西地那非片'], freq=1147)
# FreqItemset(items=['前列舒乐胶囊'], freq=1520)
# FreqItemset(items=['4维空间人体润滑液 冰爽保湿持久快感'], freq=1961)
# FreqItemset(items=['4维空间人体润滑液 冰爽保湿持久快感', '4维空间迷你G点震动棒'], freq=1753)
# FreqItemset(items=['退热贴'], freq=1354)
# FreqItemset(items=['金口健牙膏益优清新'], freq=3261)
# FreqItemset(items=['金口健牙膏益优清新', '云南白药牙膏'], freq=3120)
# FreqItemset(items=['金口健牙膏益优清新', '漱口水'], freq=3087)
# FreqItemset(items=['金口健牙膏益优清新', '漱口水', '云南白药牙膏'], freq=3085)
# FreqItemset(items=['复方丙酸氯倍他索软膏'], freq=1736)
# FreqItemset(items=['吗替麦考酚酯分散片'], freq=917)
# FreqItemset(items=['平咳贴'], freq=2484)
# FreqItemset(items=['平咳贴', '玻璃体温计'], freq=2484)
# FreqItemset(items=['平咳贴', '玻璃体温计', '儿童退热贴'], freq=2484)
# FreqItemset(items=['平咳贴', '儿童退热贴'], freq=2484)
# FreqItemset(items=['腰痛理疗贴'], freq=6206)
# FreqItemset(items=['维C银翘片'], freq=1080)
# FreqItemset(items=['克林霉素磷酸酯凝胶'], freq=1275)
# FreqItemset(items=['盐酸美金刚片'], freq=1006)
# FreqItemset(items=['盐酸多西环素片'], freq=1619)
# FreqItemset(items=['重组人表皮生长因子凝胶'], freq=1194)
# FreqItemset(items=['护肝片'], freq=1452)
# FreqItemset(items=['琥珀酸美托洛尔缓释片'], freq=2197)
# FreqItemset(items=['阿托伐他汀钙片'], freq=4320)
# FreqItemset(items=['杜蕾斯避孕套 Love大胆爱吧3只'], freq=1056)
# FreqItemset(items=['小儿氨酚黄那敏颗粒'], freq=1839)
# FreqItemset(items=['夫西地酸乳膏'], freq=2876)
# FreqItemset(items=['卤米松乳膏'], freq=1242)
# FreqItemset(items=['格列美脲片'], freq=978)
# FreqItemset(items=['盐酸文拉法辛缓释片'], freq=1146)
# FreqItemset(items=['雷贝拉唑钠肠溶片'], freq=1517)
# FreqItemset(items=['前列舒通胶囊'], freq=1960)
# FreqItemset(items=['甲硝唑凝胶'], freq=1352)
# FreqItemset(items=['双蝶天然胶乳橡胶避孕套 草莓装'], freq=3231)
# FreqItemset(items=['双蝶天然胶乳橡胶避孕套 草莓装', '双蝶天然胶乳橡胶避孕套 活力装'], freq=3217)
# FreqItemset(items=['双蝶天然胶乳橡胶避孕套 草莓装', '双蝶天然胶乳橡胶避孕套 活力装', '天然胶乳橡胶避孕套'], freq=3217)
# FreqItemset(items=['双蝶天然胶乳橡胶避孕套 草莓装', '天然胶乳橡胶避孕套'], freq=3217)
# FreqItemset(items=['苯磺酸左旋氨氯地平片'], freq=1722)
# FreqItemset(items=['戊酸雌二醇片'], freq=2444)
# FreqItemset(items=['百合康牌维生素C含片'], freq=5546)
# FreqItemset(items=['红霉素软膏'], freq=1079)
# FreqItemset(items=['美沙拉秦栓'], freq=1005)
# FreqItemset(items=['双氯芬酸钠缓释片'], freq=1274)
# FreqItemset(items=['葛洪养生论书'], freq=1560)
# FreqItemset(items=['葛洪养生论书', '足浴方剂'], freq=1476)
# FreqItemset(items=['葛洪养生论书', '足浴方剂', '桂龙药膏'], freq=1288)
# FreqItemset(items=['葛洪养生论书', '桂龙药膏'], freq=1370)
# FreqItemset(items=['盐酸曲唑酮片'], freq=1168)
# FreqItemset(items=['硝酸咪康唑乳膏'], freq=1394)
# FreqItemset(items=['辅理善瞬感传感器'], freq=2057)
# FreqItemset(items=['氯雷他定片'], freq=1787)
# FreqItemset(items=['草酸艾司西酞普兰片'], freq=3605)
# FreqItemset(items=['富马酸替诺福韦二吡呋酯片'], freq=954)
# FreqItemset(items=['复方甘草酸苷片'], freq=2677)
# FreqItemset(items=['盐酸达泊西汀片'], freq=10279)
# FreqItemset(items=['盐酸达泊西汀片', '进口诺丝避孕套 10只 惊喜装天然胶乳橡胶避孕套'], freq=2965)
# FreqItemset(items=['盐酸达泊西汀片', '枸橼酸西地那非片'], freq=2533)
# FreqItemset(items=['炔雌醇环丙孕酮片'], freq=1108)
# FreqItemset(items=['艾地苯醌片'], freq=1036)
# FreqItemset(items=['酒石酸美托洛尔片'], freq=1327)
# FreqItemset(items=['安神补脑液'], freq=1715)
# FreqItemset(items=['百令胶囊'], freq=1231)
# FreqItemset(items=['米氮平片'], freq=2411)
# FreqItemset(items=['转移因子口服溶液'], freq=1515)
# FreqItemset(items=['恩替卡韦分散片'], freq=5255)
# FreqItemset(items=['桂龙药膏'], freq=1939)
# FreqItemset(items=['沙格列汀片'], freq=998)
# FreqItemset(items=['硫酸羟氯喹片'], freq=3215)
# FreqItemset(items=['噻托溴铵粉雾剂'], freq=1168)
# FreqItemset(items=['吡美莫司乳膏'], freq=1076)
# FreqItemset(items=['甲磺酸酚妥拉明分散片'], freq=1394)
# FreqItemset(items=['卡泊三醇搽剂'], freq=1782)
# FreqItemset(items=['金水宝胶囊'], freq=1261)
# FreqItemset(items=['儿童退热贴'], freq=2672)
# FreqItemset(items=['疏肝益阳胶囊'], freq=1557)
# FreqItemset(items=['盐酸左西替利嗪片'], freq=954)
# FreqItemset(items=['桉柠蒎肠溶软胶囊'], freq=2048)
# FreqItemset(items=['六味地黄丸'], freq=9223)
# FreqItemset(items=['咽炎片'], freq=1107)
# FreqItemset(items=['苯磺酸氨氯地平片'], freq=3472)
# FreqItemset(items=['银杏叶提取物片'], freq=1325)
# FreqItemset(items=['阿昔洛韦片'], freq=1036)
# FreqItemset(items=['利培酮片'], freq=1618)
# FreqItemset(items=['阿法骨化醇软胶囊'], freq=1191)
# FreqItemset(items=['盐酸米诺环素胶囊'], freq=2145)
# FreqItemset(items=['盐酸左氧氟沙星片'], freq=1443)
# FreqItemset(items=['奥氮平片'], freq=4302)
# FreqItemset(items=['缬沙坦胶囊'], freq=1836)
# FreqItemset(items=['川贝雪梨膏'], freq=2866)
# FreqItemset(items=['川贝雪梨膏', 'VD钙片(中老年型)'], freq=2810)
# FreqItemset(items=['替米沙坦片'], freq=973)
# FreqItemset(items=['溪黄茶代用茶'], freq=1142)
# FreqItemset(items=['替比夫定片'], freq=1054)
# FreqItemset(items=['醋酸去氨加压素片'], freq=1352)
# FreqItemset(items=['柳氮磺吡啶肠溶片'], freq=1258)
# FreqItemset(items=['右归丸'], freq=1772)
# FreqItemset(items=['多巴丝肼片'], freq=1553)
# FreqItemset(items=['前列回春胶囊'], freq=2654)
# FreqItemset(items=['他达拉非片'], freq=8541)
# FreqItemset(items=['他达拉非片', '进口诺丝避孕套 10只 惊喜装天然胶乳橡胶避孕套'], freq=3116)
# FreqItemset(items=['甲钴胺片'], freq=2031)
# FreqItemset(items=['盐酸丁螺环酮片'], freq=1029)
# FreqItemset(items=['双蝶天然胶乳橡胶避孕套 活力装'], freq=3457)
# FreqItemset(items=['双蝶天然胶乳橡胶避孕套 活力装', '天然胶乳橡胶避孕套'], freq=3218)
# FreqItemset(items=['匹多莫德分散片'], freq=952)
# FreqItemset(items=['乙醇消毒液'], freq=1189)
# FreqItemset(items=['固本回元口服液'], freq=1439)
# FreqItemset(items=['吸入用异丙托溴铵溶液'], freq=1107)
# FreqItemset(items=['盐酸伐昔洛韦片'], freq=1836)
# FreqItemset(items=['维A酸乳膏'], freq=1323)
# FreqItemset(items=['奥卡西平片'], freq=2863)
# FreqItemset(items=['螺内酯片'], freq=1606)
# FreqItemset(items=['硫酸特布他林雾化液'], freq=973)
# FreqItemset(items=['云南白药创可贴'], freq=2130)
# FreqItemset(items=['硫酸沙丁胺醇吸入气雾剂'], freq=1140)
# FreqItemset(items=['盐酸特比萘芬喷雾剂'], freq=1051)
# FreqItemset(items=['还原型谷胱甘肽片'], freq=1351)
# FreqItemset(items=['云南白药牙膏'], freq=4192)
# FreqItemset(items=['知柏地黄丸'], freq=1231)
# FreqItemset(items=['甲泼尼龙片'], freq=1709)
# FreqItemset(items=['阿卡波糖片'], freq=1515)
# FreqItemset(items=['氟哌噻吨美利曲辛片'], freq=2389)
# FreqItemset(items=['小粉象 生理性海水鼻腔喷雾器'], freq=1936)
# FreqItemset(items=['小粉象 生理性海水鼻腔喷雾器', '一次性使用口罩'], freq=1749)
# FreqItemset(items=['金匮肾气丸'], freq=5241)
# FreqItemset(items=['过氧苯甲酰凝胶'], freq=3211)
# FreqItemset(items=['过氧苯甲酰凝胶', '阿达帕林凝胶'], freq=1288)
# FreqItemset(items=['厄贝沙坦氢氯噻嗪片'], freq=996)
# FreqItemset(items=['舒肝解郁胶囊'], freq=1167)
# FreqItemset(items=['祛痘调理精华液'], freq=1387)
# FreqItemset(items=['复方卡力孜然酊'], freq=1069)
# FreqItemset(items=['鬼臼毒素酊'], freq=1313)
# FreqItemset(items=['足浴方剂'], freq=1834)
# FreqItemset(items=['足浴方剂', '桂龙药膏'], freq=1616)
# FreqItemset(items=['前列安栓'], freq=2855)
# FreqItemset(items=['病从血中来'], freq=1598)
# FreqItemset(items=['病从血中来', '酿粉刺平精华水'], freq=1157)
# FreqItemset(items=['药盒'], freq=2111)
# FreqItemset(items=['布地奈德福莫特罗粉吸入剂'], freq=4173)
# FreqItemset(items=['龟龄集'], freq=1045)
# FreqItemset(items=['泮托拉唑钠肠溶片'], freq=973)
# FreqItemset(items=['达比加群酯胶囊'], freq=1228)
# FreqItemset(items=['盐酸氨基葡萄糖胶囊'], freq=1137)
# FreqItemset(items=['阿胶'], freq=1513)
# FreqItemset(items=['复方玄驹胶囊'], freq=1350)
# FreqItemset(items=['厄贝沙坦片'], freq=1909)
# FreqItemset(items=['肠内营养粉剂(TP)'], freq=1700)
# FreqItemset(items=['吸入用布地奈德混悬液'], freq=3181)
# FreqItemset(items=['诺斯清生理性海水鼻腔护理喷雾器'], freq=992)
# FreqItemset(items=['小柴胡颗粒'], freq=2368)
# FreqItemset(items=['血糖试纸'], freq=1166)
# FreqItemset(items=['醋酸泼尼松片'], freq=1378)
# FreqItemset(items=['异烟肼片'], freq=1065)
# FreqItemset(items=['盐酸帕罗西汀片'], freq=5189)
# FreqItemset(items=['克林霉素甲硝唑搽剂'], freq=1763)
# FreqItemset(items=['铝碳酸镁片'], freq=1256)
# FreqItemset(items=['盐酸文拉法辛缓释胶囊'], freq=1546)
# FreqItemset(items=['富马酸喹硫平片'], freq=2585)
# FreqItemset(items=['前列通瘀胶囊'], freq=2015)
# FreqItemset(items=['维生素C片'], freq=7537)
# FreqItemset(items=['三金片'], freq=1025)
# FreqItemset(items=['漱口水'], freq=3435)
# FreqItemset(items=['漱口水', '云南白药牙膏'], freq=3092)
# FreqItemset(items=['人初油湿巾'], freq=946)
# FreqItemset(items=['复方丹参片'], freq=1178)
# FreqItemset(items=['雅培血糖仪操作指南宣传单-瞬感二维码版'], freq=1434)
# FreqItemset(items=['雅培血糖仪操作指南宣传单-瞬感二维码版', '辅理善瞬感传感器'], freq=1433)
# FreqItemset(items=['熊去氧胆酸胶囊'], freq=1105)
# cost time:  12.853100299835205

# %%
def get_transactions_data():
    data_lst = []
    with open('./data/samples_full.txt', 'r', encoding='utf8') as file:
        cnt = 0
        for line in file:
            cnt += 1
            sss = line.strip().split('###')
            data_lst.append(tuple((cnt, sss)))
    return data_lst

data_lst = get_transactions_data()
for data in data_lst[:8]:
    print(data)
# Out:
# (1, ['清脑复神液'])
# (2, ['麝香祛风湿油'])
# (3, ['辅理善瞬感传感器', '健客家庭药箱'])
# (4, ['益康胶囊'])
# (5, ['奥氮平片'])
# (6, ['氯化钾缓释片', '呋塞米片', '妇炎洁植物本草抑菌洗液', '康复新液', '螺内酯片', '花红片'])
# (7, ['维生素C片', '阿胶'])
# (8, ['汤臣倍健蛋白粉', '约斯夫特大片创可贴(6贴装)'])

# %%
df = spark.createDataFrame(data_lst, ["id", "items"])

start_t = time.time()
fpGrowth = FPGrowth(itemsCol="items", minSupport=0.003, minConfidence=0.05)
model = fpGrowth.fit(df)
print('fp growth cost time: ', time.time()-start_t)

# Display frequent itemsets.
# model.freqItemsets.show()
model.freqItemsets.toPandas().head(50)

# Display generated association rules.
# model.associationRules.show()
model.associationRules.toPandas().head(50)

# transform examines the input items against all the association rules and summarize the
# consequents as prediction
# model.transform(df).show()
# Out:
# fp growth cost time:  4.266887187957764
#                             antecedent                  consequent  \
# 0                        [漱口水, 云南白药牙膏]                 [金口健牙膏益优清新]
# 1                         [VD钙片(中老年型)]                     [川贝雪梨膏]
# 2                          [金口健牙膏益优清新]                    [云南白药牙膏]
# 3                          [金口健牙膏益优清新]                       [漱口水]
# 4                           [咽炎片(999)]                     [健胃消食片]
# 5                           [枸橼酸西地那非片]                 [天然胶乳橡胶避孕套]
# 6                           [枸橼酸西地那非片]  [进口诺丝避孕套 10只 惊喜装天然胶乳橡胶避孕套]
# 7                               [医用棉签]                       [创口贴]
# 8                               [医用棉签]                   [一次性使用口罩]
# 9                     [金口健牙膏益优清新, 漱口水]                    [云南白药牙膏]
# 10                             [他达拉非片]  [进口诺丝避孕套 10只 惊喜装天然胶乳橡胶避孕套]
# 11                         [天然胶乳橡胶避孕套]           [双蝶天然胶乳橡胶避孕套 活力装]
# 12                         [天然胶乳橡胶避孕套]                  [枸橼酸西地那非片]
# 13                         [天然胶乳橡胶避孕套]           [双蝶天然胶乳橡胶避孕套 草莓装]
# 14                         [创口贴, 医用棉签]                   [一次性使用口罩]
# 15                   [双蝶天然胶乳橡胶避孕套 活力装]                 [天然胶乳橡胶避孕套]
# 16                   [双蝶天然胶乳橡胶避孕套 活力装]           [双蝶天然胶乳橡胶避孕套 草莓装]
# 17                           [盐酸达泊西汀片]  [进口诺丝避孕套 10只 惊喜装天然胶乳橡胶避孕套]
# 18  [双蝶天然胶乳橡胶避孕套 草莓装, 双蝶天然胶乳橡胶避孕套 活力装]                 [天然胶乳橡胶避孕套]
# 19                      [创口贴, 一次性使用口罩]                      [医用棉签]
# 20                             [川贝雪梨膏]                [VD钙片(中老年型)]
# 21          [进口诺丝避孕套 10只 惊喜装天然胶乳橡胶避孕套]                     [他达拉非片]
# 22          [进口诺丝避孕套 10只 惊喜装天然胶乳橡胶避孕套]                  [枸橼酸西地那非片]
# 23          [进口诺丝避孕套 10只 惊喜装天然胶乳橡胶避孕套]                   [盐酸达泊西汀片]
# 24                               [创口贴]                   [一次性使用口罩]
# 25                               [创口贴]                      [医用棉签]
# 26        [双蝶天然胶乳橡胶避孕套 草莓装, 天然胶乳橡胶避孕套]           [双蝶天然胶乳橡胶避孕套 活力装]
# 27                   [双蝶天然胶乳橡胶避孕套 草莓装]           [双蝶天然胶乳橡胶避孕套 活力装]
# 28                   [双蝶天然胶乳橡胶避孕套 草莓装]                 [天然胶乳橡胶避孕套]
# 29                 [金口健牙膏益优清新, 云南白药牙膏]                       [漱口水]
# 30                             [健胃消食片]                  [咽炎片(999)]
# 31                     [一次性使用口罩, 医用棉签]                       [创口贴]
# 32        [双蝶天然胶乳橡胶避孕套 活力装, 天然胶乳橡胶避孕套]           [双蝶天然胶乳橡胶避孕套 草莓装]
# 33                           [一次性使用口罩]                       [创口贴]
# 34                           [一次性使用口罩]                      [医用棉签]
# 35                            [云南白药牙膏]                 [金口健牙膏益优清新]
# 36                            [云南白药牙膏]                       [漱口水]
# 37                               [漱口水]                 [金口健牙膏益优清新]
# 38                               [漱口水]                    [云南白药牙膏]
#
#     confidence        lift
# 0     0.997736  280.488062
# 1     0.631319  201.939854
# 2     0.956762  209.233885
# 3     0.946642  252.643766
# 4     0.966049  140.955298
# 5     0.078819    6.558725
# 6     0.275680   11.225895
# 7     0.486053   65.662822
# 8     0.520677   42.414132
# 9     0.999352  218.547963
# 10    0.364828   14.856101
# 11    0.292094   77.459164
# 12    0.437052    6.558725
# 13    0.292003   82.851476
# 14    0.993259   80.910559
# 15    0.930865   77.459164
# 16    0.930576  264.036654
# 17    0.288452   11.745999
# 18    1.000000   83.212036
# 19    0.995799   80.837317
# 20    0.980461  201.939854
# 21    0.138409   14.856101
# 22    0.748057   11.225895
# 23    0.131702   11.745999
# 24    0.806808   65.722315
# 25    0.808871   65.662822
# 26    1.000000  265.185710
# 27    0.995667  264.036654
# 28    0.995667   82.851476
# 29    0.988782  263.890241
# 30    0.588731  140.955298
# 31    0.927211  125.260506
# 32    0.999689  283.646586
# 33    0.486494   65.722315
# 34    0.522481   42.414132
# 35    0.744275  209.233885
# 36    0.737595  196.852515
# 37    0.898690  252.643766
# 38    0.900146  196.852515

# %%
model.freqItemsets.toPandas().head(50)
# Out:
#                                             items   freq
# 0                                       [异维A酸软胶囊]   4508
# 1                                         [五子衍宗丸]   3172
# 2                                         [板蓝根颗粒]   3393
# 3                                         [引阳索胶囊]   3961
# 4                                          [前列安栓]   2855
# 5                                        [孟鲁司特钠片]   2794
# 6                                        [他克莫司软膏]   3037
# 7                                       [玻璃酸钠滴眼液]   3340
# 8                                         [他达拉非片]   8541
# 9               [他达拉非片, 进口诺丝避孕套 10只 惊喜装天然胶乳橡胶避孕套]   3116
# 10                                        [非布司他片]   3823
# 11                                      [恩替卡韦分散片]   5255
# 12                                      [阿托伐他汀钙片]   4320
# 13                                          [创口贴]   6786
# 14                                 [创口贴, 一次性使用口罩]   5475
# 15                           [创口贴, 一次性使用口罩, 医用棉签]   5452
# 16                                    [创口贴, 医用棉签]   5489
# 17                                       [夫西地酸乳膏]   2876
# 18                                 [布地奈德福莫特罗粉吸入剂]   4173
# 19                                       [硫酸羟氯喹片]   3215
# 20                              [双蝶天然胶乳橡胶避孕套 活力装]   3457
# 21                   [双蝶天然胶乳橡胶避孕套 活力装, 天然胶乳橡胶避孕套]   3218
# 22                                  [沙美特罗替卡松粉吸入剂]   5071
# 23                               [约斯夫特大片创可贴(6贴装)]  11762
# 24                                    [天然胶乳橡胶避孕套]  11017
# 25                          [天然胶乳橡胶避孕套, 枸橼酸西地那非片]   4815
# 26                                        [健胃消食片]   6283
# 27                              [双蝶天然胶乳橡胶避孕套 草莓装]   3231
# 28             [双蝶天然胶乳橡胶避孕套 草莓装, 双蝶天然胶乳橡胶避孕套 活力装]   3217
# 29  [双蝶天然胶乳橡胶避孕套 草莓装, 双蝶天然胶乳橡胶避孕套 活力装, 天然胶乳橡胶避孕套]   3217
# 30                   [双蝶天然胶乳橡胶避孕套 草莓装, 天然胶乳橡胶避孕套]   3217
# 31                                      [丙戊酸钠缓释片]   2918
# 32                                        [奥卡西平片]   2863
# 33                                   [吸入用布地奈德混悬液]   3181
# 34                                      [酿粉刺平精华水]   3431
# 35                                      [一次性使用口罩]  11254
# 36                                [一次性使用口罩, 医用棉签]   5880
# 37                                       [阿达帕林凝胶]   6344
# 38                                       [阿莫西林胶囊]   4578
# 39                                       [卡泊三醇软膏]   4027
# 40                                   [百合康牌维生素C含片]   5546
# 41                                        [六味地黄丸]   9223
# 42                                    [玻尿酸补水保湿面膜]   3114
# 43                                     [奥美拉唑肠溶胶囊]   3341
# 44                                        [电子体温计]   4345
# 45                                      [阿司匹林肠溶片]   3827
# 46                                     [复方利多卡因乳膏]   2799
# 47                                        [感冒灵颗粒]   7237
# 48                                     [苯磺酸氨氯地平片]   3472
# 49                     [进口诺丝避孕套 10只 惊喜装天然胶乳橡胶避孕套]  22513

# %%
start_t = time.time()
fpGrowth = FPGrowth(itemsCol="items", minSupport=0.0005, minConfidence=0.05)
model = fpGrowth.fit(df)
print('fp growth cost time: ', time.time()-start_t)

# Display frequent itemsets.
# model.freqItemsets.show()
model.freqItemsets.toPandas().head(50)

# Display generated association rules.
# model.associationRules.show()
model.associationRules.toPandas().head(50)

print(type(model.associationRules))
model.associationRules.toPandas().to_csv('./data/associationRules_0005.csv', index=False)
model.freqItemsets.toPandas().to_csv('./data/frequentItems_0005.csv', index=False)

# transform examines the input items against all the association rules and summarize the
# consequents as prediction
# model.transform(df).show()
# Out:
# fp growth cost time:  3.8965072631835938
# <class 'pyspark.sql.dataframe.DataFrame'>

# %%
print(type(model.associationRules))
model.associationRules.toPandas().to_csv('./data/associationRules.csv', index=False)
model.freqItemsets.toPandas().to_csv('./data/frequentItems.csv', index=False)
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>

# %%
# df = sqlContext.createDataFrame(data, ["features"])
df = spark.createDataFrame([
    (0, [1, 2, 5]),
    (1, [1, 2, 3, 5]),
    (2, [1, 2])
], ["id", "items"])

fpGrowth = FPGrowth(itemsCol="items", minSupport=0.5, minConfidence=0.6)
model = fpGrowth.fit(df)

# Display frequent itemsets.
model.freqItemsets.show()

# Display generated association rules.
model.associationRules.show()

# transform examines the input items against all the association rules and summarize the
# consequents as prediction
model.transform(df).show()
# Out:
# +---------+----+
# |    items|freq|
# +---------+----+
# |      [5]|   2|
# |   [5, 2]|   2|
# |[5, 2, 1]|   2|
# |   [5, 1]|   2|
# |      [2]|   3|
# |   [2, 1]|   3|
# |      [1]|   3|
# +---------+----+
#
# +----------+----------+------------------+----+
# |antecedent|consequent|        confidence|lift|
# +----------+----------+------------------+----+
# |    [5, 2]|       [1]|               1.0| 1.0|
# |    [5, 1]|       [2]|               1.0| 1.0|
# |       [5]|       [2]|               1.0| 1.0|
# |       [5]|       [1]|               1.0| 1.0|
# |       [2]|       [5]|0.6666666666666666| 1.0|
# |       [2]|       [1]|               1.0| 1.0|
# |       [1]|       [5]|0.6666666666666666| 1.0|
# |       [1]|       [2]|               1.0| 1.0|
# |    [2, 1]|       [5]|0.6666666666666666| 1.0|
# +----------+----------+------------------+----+
#
# +---+------------+----------+
# | id|       items|prediction|
# +---+------------+----------+
# |  0|   [1, 2, 5]|        []|
# |  1|[1, 2, 3, 5]|        []|
# |  2|      [1, 2]|       [5]|
# +---+------------+----------+

# %%
def get_all_transactions():
    transactions = []
    with open('./data/orders_common_titles_info_split.json', 'r', encoding='utf8') as file:
        ddd = json.load(file)
    cnt = 0
    for code in ddd:
        # transactions.append(list(ddd[code]))
        # transactions.append([str(ele) for ele in ddd[code]])
        transactions.append(tuple([str(ele) for ele in ddd[code]]))
        cnt += 1
        if cnt > 1000:
            continue
    # print('transactions is ', transactions)
    print('len of transactions is ', len(transactions))
    return transactions

# %%
transactions = get_all_transactions()
